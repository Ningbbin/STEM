# %%
import os
import temul.api as tml
import hyperspy.api as hs
import atomap.api as am
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("grayscale")

# %%
s = hs.load("./InSe.tif")
# Out:
# ERROR:hyperspy.io:If this file format is supported, please report this error to the HyperSpy developers.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_146/201392868.py in <module>
# ----> 1 s = hs.load("./InSe.tif")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io.py in load(filenames, signal_type, stack, stack_axis, new_axis_name, lazy, convert_units, escape_square_brackets, stack_metadata, load_original_metadata, show_progressbar, **kwds)
#     421     else:
#     422         # No stack, so simply we load all signals in all files separately
# --> 423         objects = [load_single_file(filename, lazy=lazy, **kwds) for filename in filenames]
#     424
#     425     if len(objects) == 1:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io.py in <listcomp>(.0)
#     421     else:
#     422         # No stack, so simply we load all signals in all files separately
# --> 423         objects = [load_single_file(filename, lazy=lazy, **kwds) for filename in filenames]
#     424
#     425     if len(objects) == 1:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io.py in load_single_file(filename, **kwds)
#     474     try:
#     475         # Try and load the file
# --> 476         return load_with_reader(filename=filename, reader=reader, **kwds)
#     477
#     478     except BaseException:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io.py in load_with_reader(filename, reader, signal_type, convert_units, load_original_metadata, **kwds)
#     494     """Load a supported file with a given reader."""
#     495     lazy = kwds.get('lazy', False)
# --> 496     file_data_list = reader.file_reader(filename, **kwds)
#     497     signal_list = []
#     498
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io_plugins/tiff.py in file_reader(filename, force_read_resolution, lazy, **kwds)
#     142         dict_list = [_read_serie(tiff, serie, filename, force_read_resolution,
#     143                                  lazy=lazy, **kwds)
# --> 144             for serie in tiff.series]
#     145
#     146     return dict_list
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io_plugins/tiff.py in <listcomp>(.0)
#     142         dict_list = [_read_serie(tiff, serie, filename, force_read_resolution,
#     143                                  lazy=lazy, **kwds)
# --> 144             for serie in tiff.series]
#     145
#     146     return dict_list
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io_plugins/tiff.py in _read_serie(tiff, serie, filename, force_read_resolution, lazy, memmap, **kwds)
#     237         # TODO: maybe just pass the memmap from tiffile?
#     238     else:
# --> 239         dc = _load_data(*data_args, memmap=memmap, **kwds)
#     240
#     241     metadata_mapping = get_metadata_mapping(page, op)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/hyperspy/io_plugins/tiff.py in _load_data(serie, is_rgb, sl, memmap, **kwds)
#     250
#     251 def _load_data(serie, is_rgb, sl=None, memmap=None, **kwds):
# --> 252     dc = serie.asarray(out=memmap)
#     253     _logger.debug("data shape: {0}".format(dc.shape))
#     254     if is_rgb:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tifffile/tifffile.py in asarray(self, level, **kwargs)
#    8871             return self.levels[level].asarray(**kwargs)
#    8872         if self.parent:
# -> 8873             result = self.parent.asarray(series=self, **kwargs)
#    8874             if self.transform is not None:
#    8875                 result = self.transform(result)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tifffile/tifffile.py in asarray(self, key, series, level, squeeze, out, maxworkers)
#    3372                 )
#    3373         elif len(pages) == 1:
# -> 3374             result = pages[0].asarray(out=out, maxworkers=maxworkers)
#    3375         else:
#    3376             result = stack_pages(pages, out=out, maxworkers=maxworkers)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tifffile/tifffile.py in asarray(self, out, squeeze, lock, maxworkers)
#    6840                 maxworkers=maxworkers,
#    6841                 sort=True,
# -> 6842                 _fullsize=False,
#    6843             ):
#    6844                 pass
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tifffile/tifffile.py in segments(self, lock, maxworkers, func, sort, _fullsize)
#    6680                 flat=True,
#    6681             ):
# -> 6682                 yield decode(segment)
#    6683         else:
#    6684             # reduce memory overhead by processing chunks of up to
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tifffile/tifffile.py in decode(args, decodeargs, keyframe, func)
#    6668                 args, decodeargs=decodeargs, keyframe=keyframe, func=func
#    6669             ):
# -> 6670                 return func(keyframe.decode(*args, **decodeargs))
#    6671
#    6672         if maxworkers is None or maxworkers < 1:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tifffile/tifffile.py in decode(exc, *args, **kwargs)
#    6293
#    6294             def decode(*args, exc=str(exc)[1:-1], **kwargs):
# -> 6295                 raise ValueError(f'{exc}')
#    6296
#    6297             return cache(decode)
#
# ValueError: <COMPRESSION.LZW: 5> requires the 'imagecodecs' package

# %%
s.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_146/1823596060.py in <module>
# ----> 1 s.plot()
#
# NameError: name 's' is not defined
